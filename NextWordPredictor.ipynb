# %%
text = '''Here are 10 key points about machine learning (ML):
Definition: Machine learning is a subset of artificial intelligence (AI) that enables systems to learn from data, identify patterns, and make decisions with minimal human intervention.
Types of ML: The three main types of machine learning are:
Supervised learning: The model is trained on labeled data (input-output pairs).
Unsupervised learning: The model finds hidden patterns or intrinsic structures in input data that has no labels.
Reinforcement learning: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties.
Training and Testing: Machine learning models are trained on a portion of data (training set) and then evaluated on unseen data (test set) to measure their performance.
Feature Engineering: Selecting and transforming relevant data features that help improve the performance of ML models is crucial for accurate predictions.
Overfitting and Underfitting:
Overfitting: The model performs well on training data but poorly on unseen data because it has learned noise or irrelevant details.
Underfitting: The model is too simple and fails to capture the underlying trend in the data.
Algorithms: Common machine learning algorithms include decision trees, support vector machines (SVM), k-nearest neighbors (KNN), neural networks, and ensemble methods like random forests and gradient boosting.
Dimensionality Reduction: Techniques like Principal Component Analysis (PCA) or t-SNE are used to reduce the number of input features while preserving essential information, improving model performance and interpretation.
Evaluation Metrics: Various metrics like accuracy, precision, recall, F1-score, and ROC-AUC are used to evaluate how well a model performs, depending on the problem (classification, regression).
Bias-Variance Tradeoff: The goal is to find the right balance between bias (error due to oversimplification) and variance (error due to complexity) to avoid both overfitting and underfitting.
Real-World Applications: Machine learning is used in various industries for applications like recommendation systems, fraud detection, autonomous driving, medical diagnosis, and weather forecasting.'''

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tkn = Tokenizer()

# %%
tkn.fit_on_texts([text])

# %%
tkn.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'learning': 3,
#  'to': 4,
#  'data': 5,
#  'of': 6,
#  'model': 7,
#  'machine': 8,
#  'is': 9,
#  'on': 10,
#  'are': 11,
#  'or': 12,
#  'in': 13,
#  'like': 14,
#  'ml': 15,
#  'a': 16,
#  'that': 17,
#  'input': 18,
#  'training': 19,
#  'performance': 20,
#  'overfitting': 21,
#  'underfitting': 22,
#  'used': 23,
#  'systems': 24,
#  'patterns': 25,
#  'with': 26,
#  'types': 27,
#  'trained': 28,
#  'has': 29,
#  'models': 30,
#  'set': 31,
#  'unseen': 32,
#  'features': 33,
#  'for': 34,
#  'performs': 35,
#  'well': 36,
#  'algorithms': 37,
#  'metrics': 38,
#  'various': 39,
#  'bias': 40,
#  'variance': 41,
#  'error': 42,
#  'due': 43,
#  'applications': 44,
#  'here': 45,
#  '10': 46,
#  'key': 47,
#  'points': 48,
#  'about': 49,
#  'definition': 50,
#  'subset': 51,
#  'artificial': 52,
#  'intelligence': 53,
#  'ai': 54,
#  'enables': 55,
#  'learn': 56,
#  'from': 57,
#  'identify': 58,
#  'make': 59,
#  'decisions': 60,
#  'minimal': 61,
#  'human': 62,
#  'intervention': 63,
#  'three': 64,
#  'main': 65,
#  'supervised': 66,
#  'labeled': 67,
#  'output': 68,
#  'pairs': 69,
#  'unsupervised': 70,
#  'finds': 71,
#  'hidden': 72,
#  'intrinsic': 73,
#  'structures': 74,
#  'no': 75,
#  'labels': 76,
#  'reinforcement': 77,
#  'learns': 78,
#  'by': 79,
#  'interacting': 80,
#  'an': 81,
#  'environment': 82,
#  'receiving': 83,
#  'feedback': 84,
#  'form': 85,
#  'rewards': 86,
#  'penalties': 87,
#  'testing': 88,
#  'portion': 89,
#  'then': 90,
#  'evaluated': 91,
#  'test': 92,
#  'measure': 93,
#  'their': 94,
#  'feature': 95,
#  'engineering': 96,
#  'selecting': 97,
#  'transforming': 98,
#  'relevant': 99,
#  'help': 100,
#  'improve': 101,
#  'crucial': 102,
#  'accurate': 103,
#  'predictions': 104,
#  'but': 105,
#  'poorly': 106,
#  'because': 107,
#  'it': 108,
#  'learned': 109,
#  'noise': 110,
#  'irrelevant': 111,
#  'details': 112,
#  'too': 113,
#  'simple': 114,
#  'fails': 115,
#  'capture': 116,
#  'underlying': 117,
#  'trend': 118,
#  'common': 119,
#  'include': 120,
#  'decision': 121,
#  'trees': 122,
#  'support': 123,
#  'vector': 124,
#  'machines': 125,
#  'svm': 126,
#  'k': 127,
#  'nearest': 128,
#  'neighbors': 129,
#  'knn': 130,
#  'neural': 131,
#  'networks': 132,
#  'ensemble': 133,
#  'methods': 134,
#  'random': 135,
#  'forests': 136,
#  'gradient': 137,
#  'boosting': 138,
#  'dimensionality': 139,
#  'reduction': 140,
#  'techniques': 141,
#  'principal': 142,
#  'component': 143,
#  'analysis': 144,
#  'pca': 145,
#  't': 146,
#  'sne': 147,
#  'reduce': 148,
#  'number': 149,
#  'while': 150,
#  'preserving': 151,
#  'essential': 152,
#  'information': 153,
#  'improving': 154,
#  'interpretation': 155,
#  'evaluation': 156,
#  'accuracy': 157,
#  'precision': 158,
#  'recall': 159,
#  'f1': 160,
#  'score': 161,
#  'roc': 162,
#  'auc': 163,
#  'evaluate': 164,
#  'how': 165,
#  'depending': 166,
#  'problem': 167,
#  'classification': 168,
#  'regression': 169,
#  'tradeoff': 170,
#  'goal': 171,
#  'find': 172,
#  'right': 173,
#  'balance': 174,
#  'between': 175,
#  'oversimplification': 176,
#  'complexity': 177,
#  'avoid': 178,
#  'both': 179,
#  'real': 180,
#  'world': 181,
#  'industries': 182,
#  'recommendation': 183,
#  'fraud': 184,
#  'detection': 185,
#  'autonomous': 186,
#  'driving': 187,
#  'medical': 188,
#  'diagnosis': 189,
#  'weather': 190,
#  'forecasting': 191}

# %%
len(tkn.word_index)
# Out:
# 191

# %%
input_sequences = []
for sentence in text.split('\n'):
    tokanized_sentences= tkn.texts_to_sequences([sentence])[0]  # Apply tokanizer on sentences
    
    for i in range(1, len(tokanized_sentences)):
        n_gram= tokanized_sentences[:i + 1]
        input_sequences.append(n_gram)

# %%
input_sequences
# Out:
# [[45, 11],
#  [45, 11, 46],
#  [45, 11, 46, 47],
#  [45, 11, 46, 47, 48],
#  [45, 11, 46, 47, 48, 49],
#  [45, 11, 46, 47, 48, 49, 8],
#  [45, 11, 46, 47, 48, 49, 8, 3],
#  [45, 11, 46, 47, 48, 49, 8, 3, 15],
#  [50, 8],
#  [50, 8, 3],
#  [50, 8, 3, 9],
#  [50, 8, 3, 9, 16],
#  [50, 8, 3, 9, 16, 51],
#  [50, 8, 3, 9, 16, 51, 6],
#  [50, 8, 3, 9, 16, 51, 6, 52],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57, 5],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57, 5, 58],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57, 5, 58, 25],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57, 5, 58, 25, 1],
#  [50, 8, 3, 9, 16, 51, 6, 52, 53, 54, 17, 55, 24, 4, 56, 57, 5, 58, 25, 1, 59],
#  [50,
#   8,
#   3,
#   9,
#   16,
#   51,
#   6,
#   52,
#   53,
#   54,
#   17,
#   55,
#   24,
#   4,
#   56,
#   57,
#   5,
#   58,
#   25,
#   1,
#   59,
#   60],
#  [50,
#   8,
#   3,
#   9,
#   16,
#   51,
#   6,
#   52,
#   53,
#   54,
#   17,
#   55,
#   24,
#   4,
#   56,
#   57,
#   5,
#   58,
#   25,
#   1,
#   59,
#   60,
#   26],
#  [50,
#   8,
#   3,
#   9,
#   16,
#   51,
#   6,
#   52,
#   53,
#   54,
#   17,
#   55,
#   24,
#   4,
#   56,
#   57,
#   5,
#   58,
#   25,
#   1,
#   59,
#   60,
#   26,
#   61],
#  [50,
#   8,
#   3,
#   9,
#   16,
#   51,
#   6,
#   52,
#   53,
#   54,
#   17,
#   55,
#   24,
#   4,
#   56,
#   57,
#   5,
#   58,
#   25,
#   1,
#   59,
#   60,
#   26,
#   61,
#   62],
#  [50,
#   8,
#   3,
#   9,
#   16,
#   51,
#   6,
#   52,
#   53,
#   54,
#   17,
#   55,
#   24,
#   4,
#   56,
#   57,
#   5,
#   58,
#   25,
#   1,
#   59,
#   60,
#   26,
#   61,
#   62,
#   63],
#  [27, 6],
#  [27, 6, 15],
#  [27, 6, 15, 2],
#  [27, 6, 15, 2, 64],
#  [27, 6, 15, 2, 64, 65],
#  [27, 6, 15, 2, 64, 65, 27],
#  [27, 6, 15, 2, 64, 65, 27, 6],
#  [27, 6, 15, 2, 64, 65, 27, 6, 8],
#  [27, 6, 15, 2, 64, 65, 27, 6, 8, 3],
#  [27, 6, 15, 2, 64, 65, 27, 6, 8, 3, 11],
#  [66, 3],
#  [66, 3, 2],
#  [66, 3, 2, 7],
#  [66, 3, 2, 7, 9],
#  [66, 3, 2, 7, 9, 28],
#  [66, 3, 2, 7, 9, 28, 10],
#  [66, 3, 2, 7, 9, 28, 10, 67],
#  [66, 3, 2, 7, 9, 28, 10, 67, 5],
#  [66, 3, 2, 7, 9, 28, 10, 67, 5, 18],
#  [66, 3, 2, 7, 9, 28, 10, 67, 5, 18, 68],
#  [66, 3, 2, 7, 9, 28, 10, 67, 5, 18, 68, 69],
#  [70, 3],
#  [70, 3, 2],
#  [70, 3, 2, 7],
#  [70, 3, 2, 7, 71],
#  [70, 3, 2, 7, 71, 72],
#  [70, 3, 2, 7, 71, 72, 25],
#  [70, 3, 2, 7, 71, 72, 25, 12],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18, 5],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18, 5, 17],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18, 5, 17, 29],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18, 5, 17, 29, 75],
#  [70, 3, 2, 7, 71, 72, 25, 12, 73, 74, 13, 18, 5, 17, 29, 75, 76],
#  [77, 3],
#  [77, 3, 2],
#  [77, 3, 2, 7],
#  [77, 3, 2, 7, 78],
#  [77, 3, 2, 7, 78, 79],
#  [77, 3, 2, 7, 78, 79, 80],
#  [77, 3, 2, 7, 78, 79, 80, 26],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2, 85],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2, 85, 6],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2, 85, 6, 86],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2, 85, 6, 86, 12],
#  [77, 3, 2, 7, 78, 79, 80, 26, 81, 82, 1, 83, 84, 13, 2, 85, 6, 86, 12, 87],
#  [19, 1],
#  [19, 1, 88],
#  [19, 1, 88, 8],
#  [19, 1, 88, 8, 3],
#  [19, 1, 88, 8, 3, 30],
#  [19, 1, 88, 8, 3, 30, 11],
#  [19, 1, 88, 8, 3, 30, 11, 28],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1, 90],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1, 90, 91],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1, 90, 91, 10],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1, 90, 91, 10, 32],
#  [19, 1, 88, 8, 3, 30, 11, 28, 10, 16, 89, 6, 5, 19, 31, 1, 90, 91, 10, 32, 5],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92,
#   31],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92,
#   31,
#   4],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92,
#   31,
#   4,
#   93],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92,
#   31,
#   4,
#   93,
#   94],
#  [19,
#   1,
#   88,
#   8,
#   3,
#   30,
#   11,
#   28,
#   10,
#   16,
#   89,
#   6,
#   5,
#   19,
#   31,
#   1,
#   90,
#   91,
#   10,
#   32,
#   5,
#   92,
#   31,
#   4,
#   93,
#   94,
#   20],
#  [95, 96],
#  [95, 96, 97],
#  [95, 96, 97, 1],
#  [95, 96, 97, 1, 98],
#  [95, 96, 97, 1, 98, 99],
#  [95, 96, 97, 1, 98, 99, 5],
#  [95, 96, 97, 1, 98, 99, 5, 33],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6, 15],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6, 15, 30],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6, 15, 30, 9],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6, 15, 30, 9, 102],
#  [95, 96, 97, 1, 98, 99, 5, 33, 17, 100, 101, 2, 20, 6, 15, 30, 9, 102, 34],
#  [95,
#   96,
#   97,
#   1,
#   98,
#   99,
#   5,
#   33,
#   17,
#   100,
#   101,
#   2,
#   20,
#   6,
#   15,
#   30,
#   9,
#   102,
#   34,
#   103],
#  [95,
#   96,
#   97,
#   1,
#   98,
#   99,
#   5,
#   33,
#   17,
#   100,
#   101,
#   2,
#   20,
#   6,
#   15,
#   30,
#   9,
#   102,
#   34,
#   103,
#   104],
#  [21, 1],
#  [21, 1, 22],
#  [21, 2],
#  [21, 2, 7],
#  [21, 2, 7, 35],
#  [21, 2, 7, 35, 36],
#  [21, 2, 7, 35, 36, 10],
#  [21, 2, 7, 35, 36, 10, 19],
#  [21, 2, 7, 35, 36, 10, 19, 5],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5, 107],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5, 107, 108],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5, 107, 108, 29],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5, 107, 108, 29, 109],
#  [21, 2, 7, 35, 36, 10, 19, 5, 105, 106, 10, 32, 5, 107, 108, 29, 109, 110],
#  [21,
#   2,
#   7,
#   35,
#   36,
#   10,
#   19,
#   5,
#   105,
#   106,
#   10,
#   32,
#   5,
#   107,
#   108,
#   29,
#   109,
#   110,
#   12],
#  [21,
#   2,
#   7,
#   35,
#   36,
#   10,
#   19,
#   5,
#   105,
#   106,
#   10,
#   32,
#   5,
#   107,
#   108,
#   29,
#   109,
#   110,
#   12,
#   111],
#  [21,
#   2,
#   7,
#   35,
#   36,
#   10,
#   19,
#   5,
#   105,
#   106,
#   10,
#   32,
#   5,
#   107,
#   108,
#   29,
#   109,
#   110,
#   12,
#   111,
#   112],
#  [22, 2],
#  [22, 2, 7],
#  [22, 2, 7, 9],
#  [22, 2, 7, 9, 113],
#  [22, 2, 7, 9, 113, 114],
#  [22, 2, 7, 9, 113, 114, 1],
#  [22, 2, 7, 9, 113, 114, 1, 115],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2, 117],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2, 117, 118],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2, 117, 118, 13],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2, 117, 118, 13, 2],
#  [22, 2, 7, 9, 113, 114, 1, 115, 4, 116, 2, 117, 118, 13, 2, 5],
#  [37, 119],
#  [37, 119, 8],
#  [37, 119, 8, 3],
#  [37, 119, 8, 3, 37],
#  [37, 119, 8, 3, 37, 120],
#  [37, 119, 8, 3, 37, 120, 121],
#  [37, 119, 8, 3, 37, 120, 121, 122],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125, 126],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125, 126, 127],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125, 126, 127, 128],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129],
#  [37, 119, 8, 3, 37, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14,
#   135],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14,
#   135,
#   136],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14,
#   135,
#   136,
#   1],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14,
#   135,
#   136,
#   1,
#   137],
#  [37,
#   119,
#   8,
#   3,
#   37,
#   120,
#   121,
#   122,
#   123,
#   124,
#   125,
#   126,
#   127,
#   128,
#   129,
#   130,
#   131,
#   132,
#   1,
#   133,
#   134,
#   14,
#   135,
#   136,
#   1,
#   137,
#   138],
#  [139, 140],
#  [139, 140, 141],
#  [139, 140, 141, 14],
#  [139, 140, 141, 14, 142],
#  [139, 140, 141, 14, 142, 143],
#  [139, 140, 141, 14, 142, 143, 144],
#  [139, 140, 141, 14, 142, 143, 144, 145],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11, 23],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11, 23, 4],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11, 23, 4, 148],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11, 23, 4, 148, 2],
#  [139, 140, 141, 14, 142, 143, 144, 145, 12, 146, 147, 11, 23, 4, 148, 2, 149],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153,
#   154],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153,
#   154,
#   7],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153,
#   154,
#   7,
#   20],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153,
#   154,
#   7,
#   20,
#   1],
#  [139,
#   140,
#   141,
#   14,
#   142,
#   143,
#   144,
#   145,
#   12,
#   146,
#   147,
#   11,
#   23,
#   4,
#   148,
#   2,
#   149,
#   6,
#   18,
#   33,
#   150,
#   151,
#   152,
#   153,
#   154,
#   7,
#   20,
#   1,
#   155],
#  [156, 38],
#  [156, 38, 39],
#  [156, 38, 39, 38],
#  [156, 38, 39, 38, 14],
#  [156, 38, 39, 38, 14, 157],
#  [156, 38, 39, 38, 14, 157, 158],
#  [156, 38, 39, 38, 14, 157, 158, 159],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162, 163],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162, 163, 11],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162, 163, 11, 23],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162, 163, 11, 23, 4],
#  [156, 38, 39, 38, 14, 157, 158, 159, 160, 161, 1, 162, 163, 11, 23, 4, 164],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166,
#   10],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166,
#   10,
#   2],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166,
#   10,
#   2,
#   167],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166,
#   10,
#   2,
#   167,
#   168],
#  [156,
#   38,
#   39,
#   38,
#   14,
#   157,
#   158,
#   159,
#   160,
#   161,
#   1,
#   162,
#   163,
#   11,
#   23,
#   4,
#   164,
#   165,
#   36,
#   16,
#   7,
#   35,
#   166,
#   10,
#   2,
#   167,
#   168,
#   169],
#  [40, 41],
#  [40, 41, 170],
#  [40, 41, 170, 2],
#  [40, 41, 170, 2, 171],
#  [40, 41, 170, 2, 171, 9],
#  [40, 41, 170, 2, 171, 9, 4],
#  [40, 41, 170, 2, 171, 9, 4, 172],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42, 43],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42, 43, 4],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42, 43, 4, 176],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42, 43, 4, 176, 1],
#  [40, 41, 170, 2, 171, 9, 4, 172, 2, 173, 174, 175, 40, 42, 43, 4, 176, 1, 41],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4,
#   178],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4,
#   178,
#   179],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4,
#   178,
#   179,
#   21],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4,
#   178,
#   179,
#   21,
#   1],
#  [40,
#   41,
#   170,
#   2,
#   171,
#   9,
#   4,
#   172,
#   2,
#   173,
#   174,
#   175,
#   40,
#   42,
#   43,
#   4,
#   176,
#   1,
#   41,
#   42,
#   43,
#   4,
#   177,
#   4,
#   178,
#   179,
#   21,
#   1,
#   22],
#  [180, 181],
#  [180, 181, 44],
#  [180, 181, 44, 8],
#  [180, 181, 44, 8, 3],
#  [180, 181, 44, 8, 3, 9],
#  [180, 181, 44, 8, 3, 9, 23],
#  [180, 181, 44, 8, 3, 9, 23, 13],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14, 183],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14, 183, 24],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14, 183, 24, 184],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14, 183, 24, 184, 185],
#  [180, 181, 44, 8, 3, 9, 23, 13, 39, 182, 34, 44, 14, 183, 24, 184, 185, 186],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187,
#   188],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187,
#   188,
#   189],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187,
#   188,
#   189,
#   1],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187,
#   188,
#   189,
#   1,
#   190],
#  [180,
#   181,
#   44,
#   8,
#   3,
#   9,
#   23,
#   13,
#   39,
#   182,
#   34,
#   44,
#   14,
#   183,
#   24,
#   184,
#   185,
#   186,
#   187,
#   188,
#   189,
#   1,
#   190,
#   191]]

# %%
from tensorflow.keras.utils import pad_sequences

# %%
max_len = max([len(i) for i in input_sequences])
max_len
# Out:
# 29

# %%
padded_input_sequences= pad_sequences(input_sequences, maxlen= max_len, padding= 'pre')
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  45,  11],
#        [  0,   0,   0, ...,  45,  11,  46],
#        [  0,   0,   0, ...,  11,  46,  47],
#        ...,
#        [  0,   0,   0, ..., 188, 189,   1],
#        [  0,   0,   0, ..., 189,   1, 190],
#        [  0,   0,   0, ...,   1, 190, 191]])

# %%
X = padded_input_sequences[:, : -1] # Only exclude last value
y = padded_input_sequences[:, -1] # Only include last value

# %%
from tensorflow.keras.utils import to_categorical
y= to_categorical(y, num_classes= 192)

# %%
X.shape, y.shape
# Out:
# ((304, 28), (304, 192))

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Input, Embedding, LSTM, Dense

# %%
model = Sequential([
    Input(shape= (28, )),
    Embedding(input_dim= 192, output_dim= 100),
    LSTM(units= 150),
    Dense(192, activation= 'softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 28, 100)             │          19,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 150)                 │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 192)                 │          28,992 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 198,792 (776.53 KB)
#  Trainable params: 198,792 (776.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer= 'adam', loss= 'categorical_crossentropy', metrics= ['accuracy'])

# %%
model.fit(X, y, epochs= 100)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.0270 - loss: 5.2547
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0613 - loss: 5.1543
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0408 - loss: 5.0007
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0422 - loss: 4.8226
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0387 - loss: 4.8550
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0604 - loss: 4.7904
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0714 - loss: 4.7368
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0971 - loss: 4.6286
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0803 - loss: 4.5797
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0669 - loss: 4.5231
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0696 - loss: 4.4789
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0870 - loss: 4.3350
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1073 - loss: 4.1465
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1295 - loss: 4.0697
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.1327 - loss: 3.8874
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1295 - loss: 3.8788
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.1694 - loss: 3.5960
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1642 - loss: 3.4796
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.2139 - loss: 3.3672
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.2062 - loss: 3.2488
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2439 - loss: 3.1526
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2574 - loss: 2.9930
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.2505 - loss: 2.8613
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3126 - loss: 2.7458
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3543 - loss: 2.6940
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3667 - loss: 2.4797
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.4402 - loss: 2.3776
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4594 - loss: 2.2977
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5607 - loss: 2.1634
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5451 - loss: 1.9950
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5578 - loss: 1.9871
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5496 - loss: 1.9223
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6726 - loss: 1.7626
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6652 - loss: 1.7287
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.7242 - loss: 1.5522
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7481 - loss: 1.5765
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7583 - loss: 1.4874
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.7805 - loss: 1.4428
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8057 - loss: 1.3302
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8350 - loss: 1.2642
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9096 - loss: 1.1878
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8894 - loss: 1.1663
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8938 - loss: 1.1458
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.8816 - loss: 1.0872
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9060 - loss: 1.0388
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9168 - loss: 1.0002
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9222 - loss: 0.9575
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9179 - loss: 0.9360
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9324 - loss: 0.8993
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9448 - loss: 0.8328
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9449 - loss: 0.8149
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9671 - loss: 0.7830
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9721 - loss: 0.7398
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9609 - loss: 0.6683
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9748 - loss: 0.6156
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9777 - loss: 0.6053
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9721 - loss: 0.5873
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9877 - loss: 0.5571
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9730 - loss: 0.5554
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9887 - loss: 0.5328
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9789 - loss: 0.5169
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9795 - loss: 0.4470
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9889 - loss: 0.4658
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9782 - loss: 0.4543
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9811 - loss: 0.4235
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9854 - loss: 0.4191
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9830 - loss: 0.3916
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9982 - loss: 0.3579
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9883 - loss: 0.3582
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9846 - loss: 0.3623
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9847 - loss: 0.3515
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9843 - loss: 0.3343
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9819 - loss: 0.3282
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9920 - loss: 0.3031
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9956 - loss: 0.2980
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9914 - loss: 0.2847
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9911 - loss: 0.2673
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9929 - loss: 0.2701
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9964 - loss: 0.2540
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9863 - loss: 0.2543
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9974 - loss: 0.2370
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9957 - loss: 0.2261
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9917 - loss: 0.2176
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9941 - loss: 0.2130
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9951 - loss: 0.2088
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9978 - loss: 0.1955
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9973 - loss: 0.1880
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9985 - loss: 0.1769
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9991 - loss: 0.1844
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9858 - loss: 0.1838
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9908 - loss: 0.1736
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9918 - loss: 0.1647
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9901 - loss: 0.1696
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9979 - loss: 0.1626
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9921 - loss: 0.1594
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9975 - loss: 0.1512
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9944 - loss: 0.1478
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9969 - loss: 0.1449
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9913 - loss: 0.1377
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9877 - loss: 0.1420

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Assume `model` and `tkn` (the tokenizer) are already defined elsewhere in your code
word = 'patterns'
max_len = 28  # Ensure this matches the max length expected by your model

for i in range(10):
    # Tokenize the input text
    token_text = tkn.texts_to_sequences([word])
    
    # Pad the tokenized sequence to the required max_len
    padded_token_text = pad_sequences(token_text, maxlen=max_len, padding='pre')
    
    # Reshape the padded sequence to match the input shape expected by the model
    # Model expects input of shape (None, 28), so we ensure the input is (1, 28)
    padded_token_text = np.array(padded_token_text)  # Ensure it's a numpy array
    padded_token_text = padded_token_text.reshape(1, max_len)  # Reshape to (1, 28)

    # Predict the next word position
    pos = np.argmax(model.predict(padded_token_text), axis=-1)
    
    # Map the predicted position back to the word
    for words, index in tkn.word_index.items():
        if index == pos:
            word = word + ' ' + words
            print(word)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# patterns and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# patterns and testing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# patterns and testing machine
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# patterns and testing machine learning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# patterns and testing machine learning models
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# patterns and testing machine learning models are
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# patterns and testing machine learning models are trained
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# patterns and testing machine learning models are trained on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# patterns and testing machine learning models are trained on a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# patterns and testing machine learning models are trained on a portion
